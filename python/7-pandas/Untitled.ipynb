# %%
# %conda search jupyter
# Out:
# Loading channels: done
# # Name                       Version           Build  Channel
# jupyter                        1.0.0          py27_0  pkgs/free
# jupyter                        1.0.0          py27_1  pkgs/free
# jupyter                        1.0.0          py27_2  pkgs/free
# jupyter                        1.0.0          py27_3  pkgs/free
# jupyter                        1.0.0          py27_4  pkgs/main
# jupyter                        1.0.0          py27_6  pkgs/main
# jupyter                        1.0.0          py27_7  pkgs/main
# jupyter                        1.0.0  py27hec63c99_0  pkgs/main
# jupyter                        1.0.0          py34_0  pkgs/free
# jupyter                        1.0.0          py34_1  pkgs/free
# jupyter                        1.0.0          py34_2  pkgs/free
# jupyter                        1.0.0          py34_3  pkgs/free
# jupyter                        1.0.0          py35_0  pkgs/free
# ...

# %%
# %conda search scipy
# Out:
# Loading channels: done
# # Name                       Version           Build  Channel
# scipy                         0.11.0      np15py26_1  pkgs/free
# scipy                         0.11.0      np15py27_1  pkgs/free
# scipy                         0.11.0      np16py26_1  pkgs/free
# scipy                         0.11.0      np16py27_1  pkgs/free
# scipy                         0.11.0      np17py26_1  pkgs/free
# scipy                         0.11.0      np17py27_1  pkgs/free
# scipy                         0.11.0      np17py33_1  pkgs/free
# scipy                       0.12.0b1      np17py26_0  pkgs/free
# scipy                       0.12.0b1      np17py27_0  pkgs/free
# scipy                         0.12.0      np15py26_0  pkgs/free
# scipy                         0.12.0      np15py27_0  pkgs/free
# scipy                         0.12.0      np16py26_0  pkgs/free
# scipy                         0.12.0      np16py27_0  pkgs/free
# ...

# %%
# %conda list envs
# Out:
# # packages in environment at /Users/abdulrahman/anaconda3/envs/data:
# #
# # Name                    Version                   Build  Channel
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda info --envs
# Out:
# # conda environments:
# #
# base                     /Users/abdulrahman/anaconda3
# Udacity                  /Users/abdulrahman/anaconda3/envs/Udacity
# data                  *  /Users/abdulrahman/anaconda3/envs/data
#
#
# Note: you may need to restart the kernel to use updated packages.
